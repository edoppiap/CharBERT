# %%
cd /content/drive/MyDrive/PoliTo/NLP_Polito/progetto/codice/CharBERT
# Out:
# /content/drive/MyDrive/PoliTo/NLP_Polito/progetto/codice/CharBERT

# %% [markdown]
# ## SST2 adv

# %%
# !python3 create_adv_dataset_tsv.py \
    --file_path ./data/glue_dataset/SST2/train.tsv \
    --output_dir ./data/glue_dataset/SST2_adv/ \
    --char_vocab ./data/dict/bert_char_vocab \
    --overwrite_output_dir
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Length of original dataset:  67349
# 100% 67349/67349 [04:04<00:00, 275.96it/s]
# num_same_word: 571411 (0.90), num_diff: 62593 (0.10)

# %% [markdown]
# ## BioMed NER adv

# %%
# !python3 create_adv_dataset_ner.py \
    --file_path ./data/ner/biomed_NER/biomed_NER.txt \
    --output_dir ./data/ner/biomed_NER_adv/ \
    --char_vocab ./data/dict/bert_char_vocab \
    --overwrite_output_dir
